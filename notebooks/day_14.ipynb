# %%
import pandas as pd

week2_summary = pd.DataFrame({
    "Module": [
        "Hybrid Forecasting",
        "Inventory Optimization",
        "Feature Importance",
        "Drift Detection",
        "Airflow Retraining"
    ],
    "Status": [
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed"
    ]
})

week2_summary
# Out:
#                    Module     Status
# 0      Hybrid Forecasting  Completed
# 1  Inventory Optimization  Completed
# 2      Feature Importance  Completed
# 3         Drift Detection  Completed
# 4      Airflow Retraining  Completed

# %%
week2_summary.to_csv(
    r"C:\Users\HP\Desktop\retailpulse_project\reports\week2_checkpoint\week2_summary.csv",
    index=False
)

# %%
performance_report = pd.DataFrame({
    "Metric": [
        "Hybrid Forecasting Model",
        "Inventory Optimization",
        "Feature Importance Analysis",
        "Drift Detection",
        "Airflow Retraining Pipeline"
    ],
    "Result": [
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed"
    ]
})

performance_report
# Out:
#                         Metric     Result
# 0     Hybrid Forecasting Model  Completed
# 1       Inventory Optimization  Completed
# 2  Feature Importance Analysis  Completed
# 3              Drift Detection  Completed
# 4  Airflow Retraining Pipeline  Completed

# %%
performance_report.to_csv(
    r"C:\Users\HP\Desktop\retailpulse_project\reports\week2_checkpoint\performance_report.csv",
    index=False
)

# %%
# visualize this checkpoint

import matplotlib.pyplot as plt

tasks = [
    "Hybrid Forecasting",
    "Inventory Optimization",
    "Feature Importance",
    "Drift Detection",
    "Airflow Pipeline"
]

status = [1, 1, 1, 1, 1]

plt.figure(figsize=(10, 5))
plt.bar(tasks, status)

plt.title("Week 2 Project Checkpoint Status")
plt.ylabel("Completion Status")
plt.xlabel("Tasks")

plt.xticks(rotation=20)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.bar(tasks, status)

plt.title("Week 2 Project Checkpoint Status")
plt.ylabel("Completion Status")
plt.xlabel("Tasks")

plt.xticks(rotation=20)
plt.tight_layout()

plt.savefig(
    r"C:\Users\HP\Desktop\retailpulse_project\reports\week2_checkpoint\week2_checkpoint_status.png"
)

plt.show()

# %%
checkpoint_report = pd.DataFrame({
    "Day": ["Day 8", "Day 10", "Day 11", "Day 12", "Day 13", "Day 14"],
    "Task": [
        "Hybrid Forecasting",
        "Inventory Optimization",
        "Feature Importance & Optuna",
        "Drift Detection",
        "Airflow Retraining Pipeline",
        "Week 2 Checkpoint"
    ],
    "Status": [
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed"
    ]
})

checkpoint_report
# Out:
#       Day                         Task     Status
# 0   Day 8           Hybrid Forecasting  Completed
# 1  Day 10       Inventory Optimization  Completed
# 2  Day 11  Feature Importance & Optuna  Completed
# 3  Day 12              Drift Detection  Completed
# 4  Day 13  Airflow Retraining Pipeline  Completed
# 5  Day 14            Week 2 Checkpoint  Completed

# %%
checkpoint_report.to_csv(
    r"C:\Users\HP\Desktop\retailpulse_project\reports\week2_checkpoint\week2_checkpoint_report.csv",
    index=False
)
